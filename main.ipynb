# %%
import pandas as pd
import numpy
df = pd.read_csv('/Users/sunita/Documents/github_repo/Chess/data/output/games.csv')
len(df)
# Out:
# 208578

# %%
df
# Out:
#        white_username     black_username  \
# 0              -Amos-      islandguimont
# 1         dawoodkamal             -Amos-
# 2              -Amos-  Aneshs-16-Knights
# 3        WarayOtokoDa             -Amos-
# 4              -Amos-    lost_in_thought
# ...               ...                ...
# 208573     jazz_man07            1051654
# 208574        1051654          death1673
# 208575        tijndeb            1051654
# 208576      fercobain            1051654
# 208577        1051654      eloisioaguiar
#
#                                              white_id  \
# 0             https://api.chess.com/pub/player/-amos-
# 1        https://api.chess.com/pub/player/dawoodkamal
# 2             https://api.chess.com/pub/player/-amos-
# 3       https://api.chess.com/pub/player/warayotokoda
# 4             https://api.chess.com/pub/player/-amos-
# ...                                               ...
# 208573    https://api.chess.com/pub/player/jazz_man07
# ...

# %%
df['rules'].unique()
# Out:
# array(['chess', 'chess960', 'threecheck', 'crazyhouse', 'kingofthehill'],
#       dtype=object)
